# %% [markdown]
# # 사전 작업
# ## Conda 환경 생성 및 패키지 설치
# 터미널에서 새로운 conda 환경 생성(anaconda prompt에서)

# %%
conda create -n paddle_env python=3.9 -y
conda activate paddle_env

# %% [markdown]
# ## 필요한 라이브러리 설치
# Conda 환경에서 필요한 모든 라이브러리를 설치

# %%
# PaddlePaddle 및 관련 패키지 설치
conda install -c conda-forge paddlepaddle-gpu
conda install -c conda-forge paddlepaddle
pip install paddleocr

# LabelImg 설치
pip install labelImg

# Scikit-learn 및 기타 필요한 패키지 설치
conda install -c conda-forge scikit-learn
conda install -c conda-forge scikit-image
conda install -c conda-forge threadpoolctl

# 폰트 설치 (필요하면 하셈)
conda install -c conda-forge font-ttf-nanum

# %% [markdown]
# # 라이브러리 설치

# %%
# %pip install paddleocr
# %pip install paddlepaddle-gpu
# !apt-get update -qq
# !apt-get install -qq fonts-nanum
# !fc-list | grep "NanumGothic"
# Out:
# Requirement already satisfied: paddleocr in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (2.7.3)
# Requirement already satisfied: shapely in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (2.0.4)
# Requirement already satisfied: scikit-image in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (0.24.0)
# Requirement already satisfied: imgaug in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (1.4.1)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (4.66.4)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (1.26.4)
# Requirement already satisfied: visualdl in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (2.5.3)
# Requirement already satisfied: rapidfuzz in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (3.9.3)
# Requirement already satisfied: opencv-python<=4.6.0.66 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: opencv-contrib-python<=4.6.0.66 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: cython in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (3.0.10)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (5.2.2)
# Requirement already satisfied: premailer in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (3.10.0)
# Requirement already satisfied: openpyxl in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (3.1.4)
# Requirement already satisfied: attrdict in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (2.0.1)
# Requirement already satisfied: Pillow>=10.0.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (10.3.0)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (6.0.1)
# Requirement already satisfied: python-docx in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (4.53.0)
# Requirement already satisfied: fire>=0.3.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (0.6.0)
# Requirement already satisfied: pdf2docx in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddleocr) (0.5.8)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from beautifulsoup4->paddleocr) (2.5)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from imgaug->paddleocr) (3.9.0)
# Requirement already satisfied: imageio in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from imgaug->paddleocr) (2.34.2)
# Requirement already satisfied: networkx>=2.8 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from scikit-image->paddleocr) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from scikit-image->paddleocr) (2024.6.18)
# Requirement already satisfied: packaging>=21 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: et-xmlfile in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from openpyxl->paddleocr) (1.1.0)
# Requirement already satisfied: PyMuPDF>=1.19.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from pdf2docx->paddleocr) (1.24.6)
# Requirement already satisfied: opencv-python-headless>=4.5 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from pdf2docx->paddleocr) (4.10.0.84)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: cssselect in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from premailer->paddleocr) (1.2.0)
# Requirement already satisfied: cssutils in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from premailer->paddleocr) (2.11.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from premailer->paddleocr) (2.32.3)
# Requirement already satisfied: cachetools in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from premailer->paddleocr) (5.3.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from tqdm->paddleocr) (0.4.6)
# Requirement already satisfied: bce-python-sdk in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (0.9.17)
# Requirement already satisfied: flask>=1.1.1 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (3.0.3)
# Requirement already satisfied: Flask-Babel>=3.0.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (4.0.0)
# Requirement already satisfied: protobuf>=3.20.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (3.20.2)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (2.2.2)
# Requirement already satisfied: rarfile in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (4.2)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from visualdl->paddleocr) (6.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (1.8.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (7.2.1)
# Requirement already satisfied: Babel>=2.12 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2.15.0)
# Requirement already satisfied: pytz>=2022.7 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2024.1)
# Requirement already satisfied: PyMuPDFb==1.24.6 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from PyMuPDF>=1.19.0->pdf2docx->paddleocr) (1.24.6)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (3.20.0)
# Requirement already satisfied: future>=0.6.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (1.0.0)
# Requirement already satisfied: more-itertools in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from cssutils->premailer->paddleocr) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from matplotlib->imgaug->paddleocr) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from matplotlib->imgaug->paddleocr) (6.4.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from pandas->visualdl->paddleocr) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from requests->premailer->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from requests->premailer->paddleocr) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from requests->premailer->paddleocr) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from requests->premailer->paddleocr) (2024.6.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: paddlepaddle-gpu in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (2.6.1)
# Requirement already satisfied: httpx in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (0.27.0)
# Requirement already satisfied: numpy>=1.13 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (10.3.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (5.1.1)
# Requirement already satisfied: astor in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (3.3.0)
# Requirement already satisfied: protobuf<=3.20.2,>=3.1.0 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from paddlepaddle-gpu) (3.20.2)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from httpx->paddlepaddle-gpu) (4.4.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from httpx->paddlepaddle-gpu) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from httpx->paddlepaddle-gpu) (1.0.5)
# Requirement already satisfied: idna in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from httpx->paddlepaddle-gpu) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from httpx->paddlepaddle-gpu) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle-gpu) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from anyio->httpx->paddlepaddle-gpu) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1 in c:\users\user\anaconda3\envs\paddle_env\lib\site-packages (from anyio->httpx->paddlepaddle-gpu) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'fc-list'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %% [markdown]
# # VScode에서 실행할 스크립트

# %% [markdown]
# ## 전체 코드

# %%
from paddleocr import PaddleOCR, draw_ocr
import cv2
import numpy as np
from PIL import ImageFont, ImageDraw, Image
from matplotlib import pyplot as plt

# %%
def plt_imshow(title='image', img=None, figsize=(8, 5)):
    plt.figure(figsize=figsize)

    if type(img) is str:
        img = cv2.imread(img)

    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []

            for i in range(len(img)):
                titles.append(title)

        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)

            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])

        plt.show()
    else:
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()

def put_text(image, text, x, y, color=(0, 255, 0), font_size=22):
    if type(image) == np.ndarray:
        color_converted = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(color_converted)

    # Use the installed NanumGothic font
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

    try:
        image_font = ImageFont.truetype(font_path, font_size)
    except IOError:
        image_font = ImageFont.load_default()

    draw = ImageDraw.Draw(image)

    try:
        draw.text((x, y), text, font=image_font, fill=color)
    except UnicodeEncodeError:
        # Fallback to default font for unsupported characters
        fallback_font = ImageFont.load_default()
        draw.text((x, y), text, font=fallback_font, fill=color)

    numpy_image = np.array(image)
    opencv_image = cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)

    return opencv_image

from paddleocr import PaddleOCR, draw_ocr
from paddleocr.paddleocr import MODEL_URLS

class MyPaddleOCR:
    def __init__(self, lang: str = "korean", **kwargs):
        self.lang = lang
        self._ocr = PaddleOCR(lang="korean", use_gpu=True, use_angle_cls = True, use_space_char = True,)
        self.img_path = None
        self.ocr_result = {}

    def get_available_langs(self):
        langs_info = []

        for idx, model_name in enumerate(list(MODEL_URLS['OCR'].keys())):
            for lang in list(MODEL_URLS['OCR'][model_name]['rec'].keys()):
                if lang not in langs_info:
                    langs_info.append(lang)

        print('Available Language : {}'.format(langs_info))

    def get_available_models(self):
        model_info = {}

        for idx, model_name in enumerate(list(MODEL_URLS['OCR'].keys())):
            model_info[model_name] = list(MODEL_URLS['OCR'][model_name]['rec'].keys())
            print('#{} Model Vesion : [{}] - Language : {}'.format(idx+1, model_name, list(MODEL_URLS['OCR'][model_name]['rec'].keys())))

    def get_ocr_result(self):
        return self.ocr_result

    def get_img_path(self):
        return self.img_path

    def show_img(self):
        plt_imshow(img=self.img_path)

    def run_ocr(self, img_path: str, debug: bool = False, raw=False):
        self.img_path = img_path
        ocr_text = []
        result = self._ocr.ocr(img_path, cls=False)
        self.ocr_result = result[0]

        if self.ocr_result:
            for r in result[0]:
                ocr_text.append(r[1][0])
        else:
            ocr_text = "No text detected."

        if debug:
            self.show_img_with_ocr()
        if raw:
          return ocr_text
        else:
          return filter_food(ocr_text)

    def show_img_with_ocr(self):
        img = cv2.imread(self.img_path)
        roi_img = img.copy()

        for text_result in self.ocr_result:
            text = text_result[1][0]
            tlX = int(text_result[0][0][0])
            tlY = int(text_result[0][0][1])
            trX = int(text_result[0][1][0])
            trY = int(text_result[0][1][1])
            brX = int(text_result[0][2][0])
            brY = int(text_result[0][2][1])
            blX = int(text_result[0][3][0])
            blY = int(text_result[0][3][1])

            pts = ((tlX, tlY), (trX, trY), (brX, brY), (blX, blY))

            topLeft = pts[0]
            topRight = pts[1]
            bottomRight = pts[2]
            bottomLeft = pts[3]

            cv2.line(roi_img, topLeft, topRight, (0, 255, 0), 2)
            cv2.line(roi_img, topRight, bottomRight, (0, 255, 0), 2)
            cv2.line(roi_img, bottomRight, bottomLeft, (0, 255, 0), 2)
            cv2.line(roi_img, bottomLeft, topLeft, (0, 255, 0), 2)
            roi_img = put_text(roi_img, text, topLeft[0], topLeft[1] - 20, font_size=15)

        plt_imshow(["Original", "ROI"], [img, roi_img], figsize=(16, 10))

# Example usage:
ocr = MyPaddleOCR()
res = ocr.run_ocr('C:/Users/user/Desktop/coupang/images/rec1.jpg', debug=False, raw=True)
# Out:
# [2024/06/28 17:34:19] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\user/.paddleocr/whl\\det\\ml\\Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\user/.paddleocr/whl\\rec\\korean\\korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\user\\anaconda3\\envs\\paddle_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\dict\\korean_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\user/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='korean', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/28 17:34:22] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.33604884147644043
# [2024/06/28 17:34:25] ppocr DEBUG: rec_res num  : 66, elapsed : 3.29044508934021

# %%
res
# Out:
# ['CoUpang',
#  'eats',
#  '객용]',
#  '1VX4BA',
#  '[수저포크0]',
#  '메뉴',
#  '수량',
#  '금액',
#  '로제이닭강정',
#  '세트',
#  '22000',
#  '허니갈릭',
#  '달콤간장',
#  '닭강경',
#  '1500',
#  '주',
#  '2단계',
#  '보통맛',
#  '0',
#  '후루룩누틀밀떡',
#  '+',
#  '치킨무0주세요',
#  '_',
#  '3',
#  '500',
#  '분모자추가',
#  '2009',
#  '수',
#  '1 500',
#  '유부추가',
#  '4개',
#  '5개',
#  '1500',
#  '메추리알',
#  '30',
#  '000',
#  '주문금액',
#  '2',
#  '700',
#  '배달비',
#  '-2',
#  '000',
#  '할인금액',
#  '-1700',
#  '배달비할인',
#  '29',
#  '000',
#  '카드결제',
#  '29000',
#  '총결제금액',
#  '거래일시:',
#  '2024-06-27',
#  '12:33:30',
#  '주문매장:',
#  '태리로제떡볶이&닭강정',
#  '교대점',
#  '결제방식',
#  '쿠페이',
#  '선결제',
#  '완료',
#  '쿠팡이츠',
#  '고객센터',
#  '1670-9827']

# %%
import re
def extract_food_names(data):
    food_names = []
    i = data.index('금액') + 1
    current_food = []

    while i < len(data):
        item = data[i]
        if re.match(r'\d+|\+|_', item):
            if current_food:
                food_names.append(' '.join(current_food))
                current_food = []
        if not re.match(r'\d+|\+|_', item):
            current_food.append(item)
        i += 1

    if current_food:
        food_names.append(' '.join(current_food))

    return food_names

# %%
def extract_food_names_until_keywords(data):
    food_names = []
    keywords = ['판매액', '주문금액', '물품']
    i = data.index('금액') + 1
    current_food = []

    while i < len(data):
        item = data[i]
        if item in keywords:
            break
        if re.match(r'\d+|\+|_', item):
            if current_food:
                food_names.append(' '.join(current_food))
                current_food = []
        if not re.match(r'\d+|\+|_', item):
            current_food.append(item)
        i += 1

    if current_food:
        food_names.append(' '.join(current_food))

    return food_names

# Example usage:
ocr = MyPaddleOCR()
res = ocr.run_ocr('C:/Users/user/Desktop/coupang/images/rec1.jpg', debug=False, raw=True)

# 음식 이름 추출 (특정 키워드 전까지만)
food_names = extract_food_names_until_keywords(res)
print(food_names)
# Out:
# [2024/06/28 17:34:39] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\user/.paddleocr/whl\\det\\ml\\Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\user/.paddleocr/whl\\rec\\korean\\korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\user\\anaconda3\\envs\\paddle_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\dict\\korean_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\user/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='korean', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/28 17:34:41] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.12202835083007812
# [2024/06/28 17:34:45] ppocr DEBUG: rec_res num  : 66, elapsed : 3.1745595932006836
# ['로제이닭강정 세트', '허니갈릭 달콤간장 닭강경', '주', '보통맛', '후루룩누틀밀떡', '치킨무0주세요', '분모자추가', '수', '유부추가', '메추리알']

# %% [markdown]
# # 미완성 코드

# %%
def extract_food_names_until_keywords(data):
    food_names = []
    keywords = ['판매액', '주문금액', '물품']
    current_food = []

    for item in data:
        if item in keywords:
            break
        if re.match(r'\d+|\+|_', item):
            if current_food:
                food_names.append(' '.join(current_food))
                current_food = []
        if not re.match(r'\d+|\+|_', item):
            current_food.append(item)

    if current_food:
        food_names.append(' '.join(current_food))

    return food_names

# Example usage:
ocr = MyPaddleOCR()
res = ocr.run_ocr('C:/Users/user/Desktop/coupang/images/rec1.jpg', debug=False, raw=True)

# 음식 이름 추출 (특정 키워드 전까지만)
food_names = extract_food_names_until_keywords(res)
print(food_names)
# Out:
# [2024/06/28 17:26:12] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\user/.paddleocr/whl\\det\\ml\\Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\user/.paddleocr/whl\\rec\\korean\\korean_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\user\\anaconda3\\envs\\paddle_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\dict\\korean_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\user/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='korean', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/06/28 17:26:14] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.10758614540100098
# [2024/06/28 17:26:18] ppocr DEBUG: rec_res num  : 66, elapsed : 3.0832643508911133
# ['CoUpang eats 객용]', '[수저포크0] 메뉴 수량 금액 로제이닭강정 세트', '허니갈릭 달콤간장 닭강경', '주', '보통맛', '후루룩누틀밀떡', '치킨무0주세요', '분모자추가', '수', '유부추가', '메추리알']
